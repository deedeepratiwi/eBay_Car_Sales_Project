# %% [markdown]
# ## German eBay Car Sales Data Project
#
# The aim of this project is to clean and analyze a dataset of used cars from eBay *Kleinanzeigen*, a classified section of the German eBay website.
#
# Dataset can be found [here](https://data.world/data-society/used-cars-data)
#
# ---
#
# Data dictionaries:
# * `dateCrawled` - When this ad was first crawled. All field-values are taken from this date.
# * `name` - Name of the car.
# * `seller` - Whether the seller is private or a dealer.
# * `offerType` - The type of listing
# * `price` - The price on the ad to sell the car.
# * `abtest` - Whether the listing is included in an A/B test.
# * `vehicleType` - The vehicle Type.
# * `yearOfRegistration` - The year in which the car was first registered.
# * `gearbox` - The transmission type.
# * `powerPS` - The power of the car in PS.
# * `model` - The car model name.
# * `kilometer` - How many kilometers the car has driven.
# * `monthOfRegistration` - The month in which the car was first registered.
# * `fuelType` - What type of fuel the car uses.
# * `brand` - The brand of the car.
# * `notRepairedDamage` - If the car has a damage which is not yet repaired.
# * `dateCreated` - The date on which the eBay listing was created.
# * `nrOfPictures` - The number of pictures in the ad.
# * `postalCode` - The postal code for the location of the vehicle.
# * `lastSeenOnline` - When the crawler saw this ad last online.
#
# ---

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Read the dataset `autos.csv` into pandas

# %%
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %% [markdown]
# #### Inspect the dataset

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# **Observations:**
#
# * The dataset consist of 20 columns, most of which are strings.
# * Some columns have null values, but not that many, less than ~20% null values.
# * There are dates that are stored as strings.
# * The column names use camelcase.

# %% [markdown]
# #### Convert column names into snakecase and rename some columns

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'ab_test',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'num_photos', 'postal_code',
       'last_seen']

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price  ab_test vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# **Changes made:**
# * Changed column names into snakecase.
# * Renamed some of the column names to make it easier to understand.

# %% [markdown]
# #### Do initial data exploration and cleaning

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price ab_test  \
# count                 50000        50000   50000      50000  50000   50000
# unique                48213        38754       2          2   2357       2
# top     2016-03-11 22:38:16  Ford_Fiesta  privat    Angebot     $0    test
# freq                      3           78   49999      49999   1421   25756
# mean                    NaN          NaN     NaN        NaN    NaN     NaN
# std                     NaN          NaN     NaN        NaN    NaN     NaN
# min                     NaN          NaN     NaN        NaN    NaN     NaN
# 25%                     NaN          NaN     NaN        NaN    NaN     NaN
# 50%                     NaN          NaN     NaN        NaN    NaN     NaN
# 75%                     NaN          NaN     NaN        NaN    NaN     NaN
# max                     NaN          NaN     NaN        NaN    NaN     NaN
#
# ...

# %% [markdown]
# **Observations:**
# * There are text columns which almost all of the values are the same (only has two unique values)
#     * `seller`
#     * `offer_type`
# * `num_photos` column looks weird and needs to be investigate further
# * `price` and `odometer` columns are supposed to be numeric columns but they have extra characters (`$`, `,`, and `km`)

# %%
autos['num_photos'].value_counts()
# Out:
# 0    50000
# Name: num_photos, dtype: int64

# %% [markdown]
# **Observations:**
#
# * Seems like `num_photos` only have 0 as values for all rows.
# * So, we are going to drop this column along with the other two columns mentioned above.

# %%
autos = autos.drop(['num_photos', 'seller', 'offer_type'], axis=1)

# %%
autos['price'] = (autos['price']
                      .str.replace('$', '')
                      .str.replace(',','')
                      .astype(int)
                 )

# %%
autos['price'].head()
# Out:
# 0    5000
# 1    8500
# 2    8990
# 3    4350
# 4    1350
# Name: price, dtype: int32

# %%
autos['odometer'] = (autos['odometer']
                        .str.replace('km','')
                        .str.replace(',','') 
                        .astype(int)
                    )

autos.rename({'odometer': 'odometer_km'}, axis=1, inplace=True)

# %%
autos['odometer_km'].head()

# %% [markdown]
# **Changes made:**
# * Dropped `num_photos`, `seller`, `offer_type` columns
# * Removed extra characters from `price` columns and converted the column to `int`
# * Removed extra characters from `odometer` columns and converted the column to `int`, also renamed column into `odometer_km`

# %% [markdown]
# #### Explore `odometer_km` and `price` column further
#
# We are going to analyze the columns using minimum and maximum values and look for any values that look unrealistically high or low (outliers) that we might want to remove.

# %%
autos['odometer_km'].unique().shape

# %%
autos['price'].unique().shape

# %%
autos['odometer_km'].value_counts()

# %% [markdown]
# **Observations:**
# * The value from `odometer_km` seems likerounded numbers which indicates that the seller probably has to choose from a dropdown list.
# * It seems like majority of the cars have higher mileage.

# %%
autos['price'].value_counts().head(20)

# %%
autos['price'].describe(include='all')

# %% [markdown]
# **Observations:**
# * There are 2357 unique values from `price` and the values are also rounded numbers.
# * There are 1421 listings with 0 price which only count for 2% of the total cars, so we might need to consider removing these.
# * The maximum value is 100 million dollars, we probably need to explore more of the high prices.

# %%
autos['price'].value_counts().sort_index(ascending=False).head(20)

# %%
autos['price'].value_counts().sort_index(ascending=True).head(20)

# %% [markdown]
# **Observations:**
# * There are a number of listings with prices below 30 dollars.
# * There are also a small number of listings with very high prices over 1 million dollars.
# * Given that eBay is an auction site, the lower prices could be the opening bid. So, we will keep the low prices, but we will remove anything above 350,000 dollar because it seems very unrealistic.

# %%
autos = autos[autos['price'].between(1,350000)]

# %%
autos['price'].describe()

# %% [markdown]
# **Changes made:**
# * Removed some outliers in `price`

# %% [markdown]
# #### Explore the date columns
#
# There are 5 columns that should represent date values:
# * `date_crawled`
# * `last_seen`
# * `ad_created`
# * `registration_month`
# * `registration_year`
#
# The `date_crawled`, `last_seen`, and `ad_created` columns are all identified as `string`. We need to convert them into a numerical data type so we can understand it quantitatively. The other two columns are already in numeric values.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
# **Observations:**
# * The first 10 characters represent the day (e.g. `2016-03-12`). To understand the date range, we can extract just the date values using `Series.value_counts()` to generate a distribution of values as percentages, and then sort by the index.

# %%
print(autos['date_crawled'].str[:10].value_counts(normalize=True, dropna=False).sort_index())
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %% [markdown]
# **Observations:**
# * It seems like the website is crawled every day from March 5th to April 7th 2016.
# * The distribution are similar.

# %%
print(autos["ad_created"].str[:10].unique().shape)

(autos["ad_created"].str[:10].value_counts(normalize=True, dropna=False).sort_index())
# Out:
# (76,)
# 2015-06-11    0.00002
# 2015-08-10    0.00002
# 2015-09-09    0.00002
# 2015-11-10    0.00002
# 2015-12-05    0.00002
#                ...
# 2016-04-03    0.03892
# 2016-04-04    0.03688
# 2016-04-05    0.01184
# 2016-04-06    0.00326
# 2016-04-07    0.00128
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# **Observations:**
# * Most listings are created within March and April
# * The oldest ads are about 9 months old.

# %%
(autos['last_seen'].str[:10].value_counts(normalize=True, dropna=False).sort_index())
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %% [markdown]
# **Observations:**
# * It seems like the website is crawled every day from March 5th to April 7th 2016.
# * The last three dates have higher percentage compared to others.

# %%
autos['registration_year'].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# **Observation:**
# * The values seems to indicate the year that the car was made.
# * There are some odd values. The minimum value is 1000 and the maximum value is 9999.
# * The cars can't be registered after the listing was created, so any rows with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
# * So, we will explore values that fall outside the 1900 - 2016 interval and see if it's safe to remove those rows.

# %%
(~autos['registration_year'].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.03944

# %% [markdown]
# **Observations:**
# * There are less than 4% of the data falls outside the interval, so we can just remove these rows.

# %%
autos = autos[autos['registration_year'].between(1900,2016)]

# %% [markdown]
# **Changes made:**
# * We only keep data with `registration_year` between 1900 - 2016

# %%
autos['registration_year'].value_counts(normalize=True)
# Out:
# 2000    0.069834
# 2005    0.062776
# 1999    0.062464
# 2004    0.056988
# 2003    0.056779
#           ...
# 1939    0.000021
# 1927    0.000021
# 1929    0.000021
# 1948    0.000021
# 1952    0.000021
# Name: registration_year, Length: 78, dtype: float64

# %% [markdown]
# **Observations:**
# * It seems like majority of the cars were registered within the last 15-20 years.

# %% [markdown]
# #### Explore `brand` columns

# %%
autos['brand'].value_counts(normalize=True)
# Out:
# volkswagen        0.212126
# bmw               0.110019
# opel              0.108166
# mercedes_benz     0.095361
# audi              0.086387
# ford              0.069793
# renault           0.047347
# peugeot           0.029524
# fiat              0.025860
# seat              0.018177
# skoda             0.016032
# mazda             0.015137
# nissan            0.015095
# citroen           0.013929
# smart             0.013909
# toyota            0.012472
# sonstige_autos    0.010952
# hyundai           0.009848
# volvo             0.009245
# mini              0.008641
# mitsubishi        0.008141
# honda             0.007850
# kia               0.007100
# alfa_romeo        0.006621
# porsche           0.006101
# suzuki            0.005913
# chevrolet         0.005705
# chrysler          0.003665
# daihatsu          0.002561
# dacia             0.002561
# jeep              0.002249
# subaru            0.002186
# land_rover        0.002040
# saab              0.001603
# ...

# %% [markdown]
# **Observations:**
# * Top five brands represent more than 50% of the overall listings.
# * There are lots of other brands that don't have a significant percentage of listings
# * So we will limit our analysis to brands representing more than 5% of total listings.

# %%
brand_counts = autos['brand'].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > 0.05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos['brand'] == brand]
    mean_price = brand_only['price'].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'volkswagen': 6516,
#  'bmw': 8334,
#  'opel': 5252,
#  'mercedes_benz': 30317,
#  'audi': 9093,
#  'ford': 7263}

# %% [markdown]
# **Observations:**
# * There are huge gap in mean prices of all the brands.
# * Mercedes Benz is the most expensive.
# * Volkswagen has an average price which can explain the popularity.

# %% [markdown]
# #### Explore `mileage` of the top brands

# %%
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=['mean_price'])
# Out:
#                mean_price
# volkswagen           6516
# bmw                  8334
# opel                 5252
# mercedes_benz       30317
# audi                 9093
# ford                 7263

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos['brand'] == brand]
    mean_mileage = brand_only['odometer_km'].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132434
# mercedes_benz        130860
# audi                 129287
# opel                 129227
# volkswagen           128730
# ford                 124046

# %%
brand_info['mean_price'] = mean_prices
brand_info
# Out:
#                mean_mileage  mean_price
# bmw                  132434        8334
# mercedes_benz        130860       30317
# audi                 129287        9093
# opel                 129227        5252
# volkswagen           128730        6516
# ford                 124046        7263

# %% [markdown]
# **Observations:**
# * The range of car mileages does not vary as much as the prices do by brand.
